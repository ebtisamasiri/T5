# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %%
# drop what left of null rows
# standerlize time col
# df = pd.Series(['Time'])
# df = pd.to_datetime(df)
# df

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
#droping Fitness_of_casuality , Work_of_casuality

df.drop(['Fitness_of_casuality', 'Work_of_casuality'], axis=1, inplace=True)

# %%
#drop rows Road_surface_type  , Area_accident_occured , Road_allignment
df = df.dropna(subset=['Road_surface_type', 'Area_accident_occured', 'Road_allignment', 'Type_of_collision'])
df.head(30)
#------
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# 7   17:20:00      Friday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 10  14:40:00    Saturday              18-30          Male   Above high school
# 11  14:40:00    Saturday              31-50          Male   Above high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# ...

# %%
# df['Educational_level'].fillna('Unknown', inplace=True)
# df['Driving_experience'].fillna('Unknown', inplace=True)
# df['Service_year_of_vehicle'].fillna('Unknown', inplace=True)
# df['Type_of_vehicle'].fillna('Unknown', inplace=True)
# df['Owner_of_vehicle'].fillna('Unknown', inplace=True)
#df['Vehicle_driver_relation '].fillna('Unknown', inplace=True)
# df.fillna('Unknown')
# df.dropna()
# df.head(50)
# Driving_experience
# Type_of_vehicle
# Owner_of_vehicle
# Area_accident_occured
#df['Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured  ' ].fillna('Unknown', inplace=True)

df['Educational_level'].fillna('Unknown', inplace=True)
df['Vehicle_driver_relation'].fillna('Unknown', inplace=True)
df['Driving_experience'].fillna('Unknown', inplace=True)
df['Type_of_vehicle'].fillna('Unknown', inplace=True)
df['Owner_of_vehicle'].fillna('Unknown', inplace=True)
df['Area_accident_occured'].fillna('Unknown', inplace=True)

df['Service_year_of_vehicle'].fillna('Unknown', inplace=True)

# %%
df['Defect_of_vehicle'].fillna('Unknown', inplace=True)

# %%
#df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].replace(['Unknown'], np.nan)
#df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].str.replace('Unkown', '')

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

df = remove_outliers(df,'Number_of_vehicles_involved')

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11637 entries, 0 to 12315
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         11637 non-null  object
#  1   Day_of_week                  11637 non-null  object
#  2   Age_band_of_driver           11637 non-null  object
#  3   Sex_of_driver                11637 non-null  object
#  4   Educational_level            11637 non-null  object
#  5   Vehicle_driver_relation      11637 non-null  object
#  6   Driving_experience           11637 non-null  object
#  7   Type_of_vehicle              11637 non-null  object
#  8   Owner_of_vehicle             11637 non-null  object
#  9   Service_year_of_vehicle      11637 non-null  object
#  10  Defect_of_vehicle            11637 non-null  object
#  11  Area_accident_occured        11637 non-null  object
#  12  Lanes_or_Medians             11317 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle                 0
# Service_year_of_vehicle          0
# Defect_of_vehicle                0
# Area_accident_occured            0
# Lanes_or_Medians               320
# Road_allignment                  0
# Types_of_Junction              831
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               293
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# ...

# %%
df['Casualty_severity'].unique()
# Out:
# array(['na', '3', '2', '1'], dtype=object)

# %%
#Defect_of_vehicle col should be an int dtype #i dropped it
#Casualty_severity col should be an int dtype


df['Casualty_severity'] = df['Casualty_severity'].replace('na',-1)
df['Casualty_severity'] = df['Casualty_severity'].astype(int)
df.dtypes['Casualty_severity']
# Out:
# dtype('int64')

# %%
df['Age_band_of_driver'].unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Age_band_of_casualty'].unique()
# Out:
# array(['na', '18-30', 'Under 18', '31-50', 'Over 51', '5'], dtype=object)

# %%
df['Accident_severity'].unique()
# Out:
# array(['Slight Injury', 'Serious Injury', 'Fatal injury'], dtype=object)

# %%
df['Accident_severity'] = df['Accident_severity'].replace('Slight Injury',1)
df['Accident_severity'] = df['Accident_severity'].replace('Serious Injury',2)
df['Accident_severity'] = df['Accident_severity'].replace('Fatal injury',3)
df['Accident_severity'] = df['Accident_severity'].astype(int)
df.dtypes['Accident_severity']
# Out:
# dtype('int64')

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr              Unknown
# 7                Employee              2-5yr           Automobile
#
#   Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12309   9:05:00      Friday              31-50        Female
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12309   Elementary school                Employee             5-10yr
# 12311             Unknown                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#         Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  \
# 12309  Pick up upto 10Q            Owner                 Unknown
# ...

# %%
df.sample()
# Out:
#          Time Day_of_week Age_band_of_driver Sex_of_driver Educational_level  \
# 7953  8:20:00     Tuesday              31-50          Male       High school
#
#      Vehicle_driver_relation Driving_experience  Type_of_vehicle  \
# 7953                   Owner             5-10yr  Lorry (41?100Q)
#
#      Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 7953            Owner                 Unknown         No defect
#
#      Area_accident_occured             Lanes_or_Medians  \
# 7953          Office areas  Double carriageway (median)
#
#                      Road_allignment Types_of_Junction Road_surface_type  \
# 7953  Tangent road with flat terrain       No junction     Asphalt roads
#
#      Road_surface_conditions Light_conditions Weather_conditions  \
# 7953                     Dry         Daylight             Normal
#
#                    Type_of_collision  Number_of_vehicles_involved  \
# 7953  Vehicle with vehicle collision                            2
#
# ...

# %%
df[['Day_of_week']].value_counts()
# Out:
# Day_of_week
# Friday         1921
# Thursday       1758
# Wednesday      1750
# Tuesday        1664
# Monday         1590
# Saturday       1579
# Sunday         1375
# Name: count, dtype: int64

# %%
df[['Sex_of_driver']].value_counts()
# Out:
# Sex_of_driver
# Male             10814
# Female             655
# Unknown            168
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties  Casualty_severity  \
# count                 11637.000000          11637.000000       11637.000000
# mean                      2.041248              1.551259           1.492739
# std                       0.689396              1.007648           1.888082
# min                       1.000000              1.000000          -1.000000
# 25%                       2.000000              1.000000          -1.000000
# 50%                       2.000000              1.000000           3.000000
# 75%                       2.000000              2.000000           3.000000
# max                       7.000000              8.000000           3.000000
#
#        Accident_severity
# count       11637.000000
# mean            1.166710
# std             0.405847
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             1.000000
# max             3.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                              Number_of_vehicles_involved  \
# Number_of_vehicles_involved                     1.000000
# Number_of_casualties                            0.212466
# Casualty_severity                              -0.004920
# Accident_severity                              -0.096762
#
#                              Number_of_casualties  Casualty_severity  \
# Number_of_vehicles_involved              0.212466          -0.004920
# Number_of_casualties                     1.000000           0.012516
# Casualty_severity                        0.012516           1.000000
# Accident_severity                        0.050343           0.014253
#
#                              Accident_severity
# Number_of_vehicles_involved          -0.096762
# Number_of_casualties                  0.050343
# Casualty_severity                     0.014253
# Accident_severity                     1.000000

# %%
df = df.select_dtypes(include=['number']) #(?)
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
# df['Number_of_vehicles_involved'].plot.hist()
# plt.title('Number of vehicles involved')

sns.histplot(df['Number_of_vehicles_involved'])
plt.title('Number of vehicles involved')
# Out:
# Text(0.5, 1.0, 'Number of vehicles involved')

# %%
# plt.figure(figsize=(16, 12))
# plt.subplot(2, 2, 2)
sns.histplot(df['Number_of_casualties'], bins=10)
plt.title('Number of casualties')
# Out:
# Text(0.5, 1.0, 'Number of casualties')

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df = df.select_dtypes(include=['number']) #(?)
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Driving_experience', y='Accident_severity', palette='muted')
plt.xlabel('Driving_experience')
plt.ylabel('Accident_severity')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-249-fb4084c90180>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Driving_experience', y='Accident_severity', palette='muted')

# %%
sns.scatterplot(x='Type_of_vehicle', y='Accident_severity', data=df)
# Out:
# <Axes: xlabel='Casualty_severity', ylabel='Accident_severity'>

# %%
sns.violinplot(data=df, y='Number_of_casualties')
# Out:
# <Axes: ylabel='Number_of_casualties'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#There is a negative relation between number of vehicles involved and the accident severity,


# Sex_of_driver
# Male             10814
# Female             655
# Unknown            168
# Name: count, dtype: int64


# Male drivers have high rate of xxx compared to female drivers

#usually there's two cars involved
